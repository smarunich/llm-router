# %% [markdown]
# # Introduction

# %% [markdown]
# Ever struggled to decide which LLM to use for a specific task? In an ideal world the most accurate model would also be the cheapest and fastest, but in practice modern agentic AI systems have to make trade-offs between accuracy, speed, and cost.
#
# This blueprint provides a router that automates these tradeoffs by routing user prompts between different LLMs. Given a user prompt, the router:
#
# - applies a policy (eg task classification or intent classification)
# - uses a router trained for that policy to map the prompt to an appropriate LLM
# - proxies the prompt to the identified fit-for-purpose LLM
#
# For example, using a task classification policy, the following user prompts can be classified into tasks and directed to the appropriate model.
#
# | User Prompt | Task Classification | Route To |
# |---|---|---|
# | "Help me write a python function to load salesforce data into my warehouse." | Code Generation | deepseek |
# | "Tell me about your return policy " | Open QA | llama 70B |
# | "Rewrite the user prompt to be better for an LLM agent. User prompt: what is the best coffee recipe" | Rewrite | llama 8B |
#
# The key features of the LLM Router are:
#
# - OpenAI API compliant: use the LLM Router as a drop-in replacement in code regardless of which LLM framework you use.
# - Flexible: use the default policy and router, or create your own policy and fine tune a router. We expect additional trained routers to be available from the community as well.
# - Configurable: easily configure which backend models are available.
# - Performant: LLM Router uses Rust and NVIDIA Triton Inference Server to add minimal latency compared to routing requests directly to a model.
#
# This notebook will walk you through deploying the router and making sample requests. We will also outline common trouble shooting steps and metrics that are available to monitor the router. The blueprint also includes an example client application, an example loadtest, and details on how to customize the router policies.

# %% [markdown]
# # Getting Started
# >[Prerequisites](#Prerequisites)
# >[Understand the blueprint](#Understand-the-blueprint)
# >[Spin up blueprint](#Spin-up-the-blueprint)
# >[Test the LLM Router](#Test-the-LLM-Router)
# >[Use the example app](#Use-the-example-app)
# >[View metrics](#View-metrics)
# >[Next Steps](#Next-Steps)
# >[Shutting down blueprint](#Stopping-Services-and-Cleaning-Up)
# ________________________

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ### Clone repository

# %%
# !git clone https://github.com/NVIDIA-AI-Blueprints/llm-router.git
# Out:
# Cloning into 'llm-router'...
# remote: Enumerating objects: 447, done.
# remote: Counting objects: 100% (447/447), done.
# remote: Compressing objects: 100% (301/301), done.
# remote: Total 447 (delta 185), reused 382 (delta 126), pack-reused 0 (from 0)
# Receiving objects: 100% (447/447), 1.60 MiB | 6.45 MiB/s, done.
# Resolving deltas: 100% (185/185), done.

# %% [markdown]
# ### Navigate to the repo root directory

# %%
# %%bash
#
# cd llm-router/

# %% [markdown]
# ### Install software

# %% [markdown]
# 1. Install **[Docker](https://docs.docker.com/engine/install/ubuntu/)**
#
# <div class="alert alert-block alert-success">
#     <b>Tip:</b> Ensure the Docker Compose plugin version is 2.29.1 or higher.  Run docker compose version to confirm. Refer to Install the Compose plugin Docker documentation for more information.

# %% [markdown]
# 2. Install **[NVIDIA Container Toolkit](https://docs.nvidia.com/datacenter/cloud-native/container-toolkit/latest/install-guide.html#installing-the-nvidia-container-toolkit)** to configure Docker for GPU-accelerated containers.
#  If you are using a system deployed with Brev you can skip this step since Brev systems come with NVIDIA Container Toolkit preinstalled.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Note:</b> After installing the toolkit, follow the instructions in the Configure Docker section in the NVIDIA Container Toolkit documentation.

# %% [markdown]
# 3. Make sure necessary python packages mentioned in requirements.txt are installed

# %%
# !cd llm-router && pip install -r requirements.txt
# Out:
# WARNING: Ignoring invalid distribution -lama-index-core (/Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages)
# Requirement already satisfied: openai in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (1.60.2)
# Requirement already satisfied: numpy in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: transformers in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (4.45.1)
# Requirement already satisfied: pyyaml in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (6.0.2)
# Requirement already satisfied: jupyter in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (1.1.1)
# Requirement already satisfied: tritonclient[http] in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (2.55.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from openai->-r requirements.txt (line 1)) (4.6.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from openai->-r requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from openai->-r requirements.txt (line 1)) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from openai->-r requirements.txt (line 1)) (0.6.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from openai->-r requirements.txt (line 1)) (2.10.4)
# Requirement already satisfied: sniffio in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from openai->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from openai->-r requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from openai->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: python-rapidjson>=0.9.1 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from tritonclient[http]->-r requirements.txt (line 2)) (1.20)
# Requirement already satisfied: urllib3>=2.0.7 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from tritonclient[http]->-r requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.1 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from tritonclient[http]->-r requirements.txt (line 2)) (3.11.11)
# Requirement already satisfied: geventhttpclient>=2.3.3 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from tritonclient[http]->-r requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: filelock in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 4)) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 4)) (0.25.1)
# Requirement already satisfied: packaging>=20.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 4)) (24.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 4)) (2024.9.11)
# Requirement already satisfied: requests in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 4)) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 4)) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 4)) (0.20.0)
# Requirement already satisfied: notebook in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 6)) (7.3.2)
# Requirement already satisfied: jupyter-console in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 6)) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 6)) (7.16.6)
# Requirement already satisfied: ipykernel in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 6)) (6.29.4)
# Requirement already satisfied: ipywidgets in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 6)) (8.1.3)
# Requirement already satisfied: jupyterlab in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 6)) (4.3.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->-r requirements.txt (line 2)) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->-r requirements.txt (line 2)) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->-r requirements.txt (line 2)) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->-r requirements.txt (line 2)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->-r requirements.txt (line 2)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->-r requirements.txt (line 2)) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->-r requirements.txt (line 2)) (1.18.3)
# Requirement already satisfied: idna>=2.8 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: gevent in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from geventhttpclient>=2.3.3->tritonclient[http]->-r requirements.txt (line 2)) (24.11.1)
# Requirement already satisfied: certifi in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from geventhttpclient>=2.3.3->tritonclient[http]->-r requirements.txt (line 2)) (2024.8.30)
# Requirement already satisfied: brotli in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from geventhttpclient>=2.3.3->tritonclient[http]->-r requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: httpcore==1.* in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 1)) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers->-r requirements.txt (line 4)) (2024.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 1)) (2.27.2)
# Requirement already satisfied: appnope in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (8.24.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (1.6.0)
# Requirement already satisfied: psutil in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (26.0.3)
# Requirement already satisfied: tornado>=6.1 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 6)) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 6)) (3.0.13)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyter-console->jupyter->-r requirements.txt (line 6)) (3.0.43)
# Requirement already satisfied: pygments in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyter-console->jupyter->-r requirements.txt (line 6)) (2.18.0)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 6)) (2.0.4)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 6)) (3.1.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 6)) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 6)) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 6)) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 6)) (0.2.4)
# Requirement already satisfied: setuptools>=40.8.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 6)) (75.1.0)
# Requirement already satisfied: tomli>=1.2.2 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 6)) (2.2.1)
# Requirement already satisfied: beautifulsoup4 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 6)) (6.2.0)
# Requirement already satisfied: defusedxml in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from requests->transformers->-r requirements.txt (line 4)) (3.3.2)
# Requirement already satisfied: webencodings in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 6)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: decorator in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (0.19.1)
# Requirement already satisfied: stack-data in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (4.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 6)) (4.2.2)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 6)) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 6)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 6)) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 6)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 6)) (0.21.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 6)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 6)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 6)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 6)) (0.10.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 6)) (4.23.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter->-r requirements.txt (line 6)) (2.21.1)
# Requirement already satisfied: wcwidth in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->-r requirements.txt (line 6)) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 6)) (2.5)
# Requirement already satisfied: zope.event in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from gevent->geventhttpclient>=2.3.3->tritonclient[http]->-r requirements.txt (line 2)) (5.0)
# Requirement already satisfied: zope.interface in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from gevent->geventhttpclient>=2.3.3->tritonclient[http]->-r requirements.txt (line 2)) (7.2)
# Requirement already satisfied: greenlet>=3.1.1 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from gevent->geventhttpclient>=2.3.3->tritonclient[http]->-r requirements.txt (line 2)) (3.1.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 6)) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 6)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 6)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 6)) (0.20.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 6)) (3.2.1)
# Requirement already satisfied: rfc3339-validator in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 6)) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel->jupyter->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: fqdn in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: isoduration in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 6)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 6)) (2.4)
# Requirement already satisfied: uri-template in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 6)) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 6)) (1.17.1)
# Requirement already satisfied: pycparser in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 6)) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 6)) (2.9.0.20241206)
# WARNING: Ignoring invalid distribution -lama-index-core (/Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -lama-index-core (/Users/dglogowski/.pyenv/versions/3.10.13/lib/python3.10/site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Get API Keys
#
# #### NVIDIA NGC Catalog key
#
# The NVIDIA NGC API Key is used in this blueprint in order to pull the default router models from NGC as well as the NVIDIA Triton Inference Server docker image which is used to run those models. Refer to [Generating NGC API Keys](https://docs.nvidia.com/ngc/gpu-cloud/ngc-user-guide/index.html#generating-api-key) in the NVIDIA NGC User Guide for more information.
#
#
# Authenticate with the NVIDIA Container Registry with the following command:

# %%
# !docker login nvcr.io --username  '$oauthtoken' --password "ENTER YOUR NGC API KEY HERE"

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Note:</b> Use oauthtoken as the username and your API key as the password. The $oauthtoken username is a special name that indicates that you will authenticate with an API key and not a user name and password. After installing the toolkit, follow the instructions in the Configure Docker section in the NVIDIA Container Toolkit documentation.

# %% [markdown]
# #### NVIDIA API Catalog key
#
# The LLM router is responsible for routing requests between foundational LLM models. In this example, we will use NVIDIA NIMs. In order to access these LLMs we will use a NVIDIA API Catalog key, which is separate from the NVIDIA NGC API key used above. You can alternatively use other LLM models or even on-premise models. To do so, you would update the router configuration file which will be discussed later.

# %% [markdown]
# 1. Navigate to **[NVIDIA API Catalog](https://build.nvidia.com/explore/discover)**.

# %% [markdown]
# 2. Select a model, such as llama3-8b-instruct.

# %% [markdown]
# 3. Select an **Input** option. The following example is of a model that offers a Docker option. Not all of the models offer this option, but all include a “Get API Key” link

# %% [markdown]
# <img src="https://docscontent.nvidia.com/dims4/default/d6307a8/2147483647/strip/true/crop/1920x919+0+0/resize/2880x1378!/format/webp/quality/90/?url=https%3A%2F%2Fk3-prod-nvidia-docs.s3.us-west-2.amazonaws.com%2Fbrightspot%2Fsphinx%2F00000192-bfa6-da2c-a1f2-ffbf41aa0000%2Fnim%2Flarge-language-models%2Flatest%2F_images%2Fbuild_docker_tab.png" />

# %% [markdown]
# 3. Click **Get API Key**.

# %% [markdown]
# <img src="https://docscontent.nvidia.com/dims4/default/c6e2096/2147483647/strip/true/crop/1920x919+0+0/resize/2880x1378!/format/webp/quality/90/?url=https%3A%2F%2Fk3-prod-nvidia-docs.s3.us-west-2.amazonaws.com%2Fbrightspot%2Fsphinx%2F00000192-bfa6-da2c-a1f2-ffbf41aa0000%2Fnim%2Flarge-language-models%2Flatest%2F_images%2Fbuild_get_api_key.png" />

# %% [markdown]
# 4. Select **"Generate Key"**

# %% [markdown]
# <img src="https://docscontent.nvidia.com/dims4/default/e7c4057/2147483647/strip/true/crop/1920x919+0+0/resize/2880x1378!/format/webp/quality/90/?url=https%3A%2F%2Fk3-prod-nvidia-docs.s3.us-west-2.amazonaws.com%2Fbrightspot%2Fsphinx%2F00000192-bfa6-da2c-a1f2-ffbf41aa0000%2Fnim%2Flarge-language-models%2Flatest%2F_images%2Fbuild_generate_key.png" />

# %% [markdown]
# 5. **Copy your key** and store it in a secure place. Do not share it.

# %% [markdown]
# <img src="https://docscontent.nvidia.com/dims4/default/4b0710a/2147483647/strip/true/crop/1920x919+0+0/resize/2880x1378!/format/webp/quality/90/?url=https%3A%2F%2Fk3-prod-nvidia-docs.s3.us-west-2.amazonaws.com%2Fbrightspot%2Fsphinx%2F00000192-bfa6-da2c-a1f2-ffbf41aa0000%2Fnim%2Flarge-language-models%2Flatest%2F_images%2Fbuild_copy_key.png" />

# %% [markdown]
# ## Understand the blueprint
#
# The LLM Router is composed of three components:
#
# - <b>Router Controller</b> - is a service similar to a proxy that routes OpenAI compatible requests.
# - <b>Router Server</b> - is a service that classifies the user's prompt according to a routing strategy and policy. The classification is made using a pre-trained model.
# - <b>Downstream LLMs</b> - are the LLMs the prompt will be routed to, typically foundational LLMs.
#
# These three components are all managed in the LLM Router configuration file which is located at `src/router-controller/config.yml`.
#
# ```yaml
# policies:
#   - name: "task_router"
#     url: http://router-server:8000/v2/models/task_router_ensemble/infer
#     llms:
#       - name: Brainstorming
#         api_base: https://integrate.api.nvidia.com
#         api_key:
#         model: meta/llama-3.1-70b-instruct
#       - name: Chatbot
#         api_base: https://integrate.api.nvidia.com
#         api_key:
#         model: mistralai/mixtral-8x22b-instruct-v0.1
#     ...
#   - name: "complexity_router"
#     url: http://router-server:8000/v2/models/complexity_router_ensemble/infer
#     llms:
#       - name: Creativity
#         api_base: https://integrate.api.nvidia.com
#         api_key:
#         model: meta/llama-3.1-70b-instruct
#       - name: Reasoning
#         api_base: https://integrate.api.nvidia.com
#         api_key:
#         model: deepseek-ai/deepseek-r1
#     ...
# ```
#
# ### Policies
#
# The configuration file specifies the routing policies. In the default configuration, a prompt can either be classified using a `task_router` policy or a `complexity_router` policy.
#
# The `task_router` uses a pre-trained model that will be deployed at `http://router-server:8000/v2/models/task_router_ensemble/infer`. The model classifies prompts into categories based on the task of the prompt:
#   - Brainstorming
#   - Chatbot
#   - Classification
#   - Closed QA
#   - Code Generation
#   - Extraction
#   - Open QA
#   - Other
#   - Rewrite
#   - Summarization
#   - Text Generation
#   - Unknown
#
# For example, the prompt `Help me write a python function to load salesforce data into my warehouse` would be classified as a `Code Generation` task.
#
# The `complexity_router` uses a different pre-trained model that will be deployed at `http://router-server:8000/v2/models/complexity_router_ensemble/infer`. This model classifies prompts into categories based on the complexity of the prompt:
#   - Creativity: Prompts that require create knowledge, eg "write me a science fiction story".
#   - Reasoning: Prompts that require reasoning, eg solving a riddle.
#   - Contextual-Knowledge: Prompts that require background information, eg asking for technical help with a specific product.
#   - Few-Shot: Prompts that include example questions and answers.
#   - Domain-Knowledge: Prompts that require broad domain knowledge, such as asking for an explanation of a historical event.
#   - No-Label-Reason: Prompts that are not classified into one of the other categories.
#   - Constraint: Prompts that include specific constraints, eg requesting an answer in a haiku format.
#
# The `customize/README.md` describes how to create your own policy and classification model, providing an example showing a policy for classifying user interactions with a bank support chatbot.
#
# ### LLMs
#
# The `llms` portion of the configuration file specifies where the classified prompts should be routed. For example, in the default configuration file:
#
# ```yaml
# policies:
#   - name: "task_router"
#     url: http://router-server:8000/v2/models/task_router_ensemble/infer
#     llms:
#       - name: Brainstorming
#         api_base: https://integrate.api.nvidia.com
#         api_key:
#         model: meta/llama-3.1-70b-instruct
#       - name: Chatbot
#         api_base: https://integrate.api.nvidia.com
#         api_key:
#         model: mistralai/mixtral-8x22b-instruct-v0.1
# ```
#
# A prompt sent to the `task_router` policy classified as a Brainstorming task would be proxied to the NVIDIA NIM `meta/llama-3.1-70b-instruct` whereas a prompt classified as a Chatbot task would be sent to `mistralai/mixtral-8x22b-instruct-v0.1`.
#
# ### Using the router
#
# The LLM Router is compatible with OpenAI API requests. This means that any applications or code that normally use an OpenAI API client (such as LangChain) can use LLM Router with minimal modification. For example, this RESTful API request to LLM Router follows the OpenAI specification with a few modifications:
#
# ```console
# curl -X 'POST' \
#   'http://0.0.0.0:8084/v1/chat/completions' \   # the URL to the deployed LLM router
#   -H 'accept: application/json' \
#   -H 'Content-Type: application/json' \
#   -d '{
#     "model": "",                                # the model field is left blank, as the LLM router will add this based on the prompt classification
#     "messages": [
#       {
#         "role":"user",
#         "content":"Hello! How are you?"
#       },
#       {
#         "role":"assistant",
#         "content":"Hi! I am quite well, how can I help you today?"
#       },
#       {
#         "role":"user",
#         "content":"Can you write me a song? Use as many emojis as possible."
#       }
#     ],
#     "max_tokens": 64,
#     "stream": true,
#     "nim-llm-router": {"policy": "task_router",
#                        "routing_strategy": "triton",
#                        "model": ""}
#   }'
# ```
#
# The primary modification is the inclusion of the `nim-llm-router` metadata in the body of the request. In most python clients this metadata would be added as `extra_body`, see `src/test_router.py` for an example. The required metadata is:
#
# - policy: the policy to use for classification, by default either `task_router`  or `complexity_router`.
# - routing_strategy: either `triton` which means the prompt is sent to a model for classification or `manual` which means that the classification is skipped - use this if the client needs to make a manual over-ride
# - model: if the `routing_strategy` is `triton` leave this blank, if the routing strategy is `manual` specify the model over-ride

# %% [markdown]
# ## Spin up the blueprint
# Docker compose scripts are provided which spin up the LLM Router microservices on a single node. Make commands are provided for convenience that use the docker compose scripts.
#
# ### Download the artifacts
#
# Start by adding your NGC API key to the commmand below and then running the `make download` command. This command will configure the NGC CLI and then download the pre-trained models for the task and complexity router policies.

# %%
# !export NGC_CLI_API_KEY="ENTER YOUR NVIDIA API KEY HERE" && export NGC_CLI_ORG="nvidia/nemo" && cd llm-router && make download

# %% [markdown]
# To confirm the command ran successfully, inspect the `routers` directory. The original folder was empty, but it should now include folders for each router policy.

# %%
# !cd llm-router && ls ./routers

# %% [markdown]
# Expected output:
#
# ```
# complexity_router  complexity_router_ensemble  postprocessing_complexity_router  postprocessing_task_router  preprocessing_complexity_router  preprocessing_task_router  readme.md  task_router  task_router_ensemble
# ```

# %% [markdown]
# ### Update the configuration
#
# The default LLM Router configuration uses NVIDIA NIMs as the foundational LLMs used to respond to user prompts. In order to access these LLMs we need to add the NVIDIA API key to the router configuration. Enter your NVIDIA API key and then run the script below. This script updates the router controller configuration file located at `src/router-controller/config.yaml`. Note that you can use other LLMs as well, including locally hosted NVIDIA NIMs or 3rd party LLMs that are OpenAI API compatible; in these cases, update the configuration file manually.
#
# <div class="alert alert-block alert-success">
#     <b>Tip:</b> The NVIDIA API key to enter begins with the letters nvapi-.

# %%
# !export NVIDIA_API_KEY="ENTER YOUR NVIDIA API KEY HERE" && cd llm-router && python3 src/update_config_yaml_helper.py

# %% [markdown]
# ### Start the services
#
# Next, run the `make up` command. This command will run docker compose to start the router controller and router server.
#
# <div class="alert alert-block alert-success">
#     <b>Note:</b> The first time you run this command the docker images needs to be pulled and built. This step could take up to 20 minutes!

# %%
# !cd llm-router && make up > /dev/null 2>&1

# %% [markdown]
# To validate the deployment of the blueprint, execute the following command to ensure the container are running.

# %%
# !docker ps --format "table {{{{.ID}}}}\t{{{{.Names}}}}\t{{{{.Status}}}}"

# %% [markdown]
# This command should produce similiar output in the following format:

# %% [raw]
# CONTAINER ID   NAMES                            STATUS
# 5498c569db5e   llm-router-router-controller-1   Up 6 minutes
# 526f6e76dbe0   llm-router-router-server-1       Up 6 minutes

# %% [markdown]
# If the either service fails to start or remain running you can check the service logs, for example:

# %%
# !cd llm-router && docker compose logs router-controller

# %% [markdown]
# ## Test the LLM Router
#
# Now that the services are running, we can use Python to create prompts and pass them to the router. The following code will send the prompt to the task router policy. The classified prompt will then be forwarded to the appropriate LLM, and the response will be sent back.
#
# <div class="alert alert-block alert-success">
#     <b>Troubleshooting:</b>  If any of the steps fail there are a few options for debugging:
#     <li> Start by running <code> docker compose logs router-controller </code>. This command will show the logs from the router controller microservice. The log details the steps a request takes including prompt classification and the proxied request to the LLM. </li>
#     <li> The router-controller logs may indicate that the request failed to be classified, typically with an error message related to the Triton service. In this case, run <code> docker compose logs router-server </code>. You may need to try re-downloading the router models, or double checking that the GPU hardware requirements for the router server are satisfied. </li>
#     <li> The router-controller logs may indicate that the request was correctly classified, but then failed during the proxied LLM call. Typical indications would be a 403, 404, or 500 error message. In this case, double check that the router controller configuration file has appropriate URLs for the LLM including a valid api key and valid model names. If you encounter a 500 error message, re-trying the code may be sufficient. </li>
# </div>

# %%
from openai import OpenAI
import os
from typing import Literal 

def make_request_to_router(PROMPT: str, policy: Literal['task_router', 'complexity_router']): 
    """ make a request to a LLM through the LLM router """
    
    client = OpenAI(
        api_key="open-ai-placeholder", # can leave this place holder as-is, the API key for the proxied LLM is pulled from the router configuration file
        max_retries=0,
        base_url="http://127.0.0.1:8084/v1/" # the url for the router-controller running locally
    )

    messages=[
        {
            "role":"user",
            "content": PROMPT
        }
    ]

    extra_body = {
        "nim-llm-router": {
            "policy": policy,     
            "routing_strategy": "triton", 
        }
    }

    try:
        chat_completion = client.chat.completions.with_raw_response.create(
        messages=messages,
        model="",
        extra_body=extra_body
        )
    except Exception as e:
        print("\nError Response:")
        if hasattr(e, 'response'):
            print(f"Status Code: {e.response.status_code}")
            print(f"Error Message: {e.response.text}")
        else:
            print(f"Error: {str(e)}")
    
    chosen_classifier = chat_completion.headers.get('X-Chosen-Classifier')

    completion = chat_completion.parse()
    
    return completion, chosen_classifier

PROMPT = "Write a python function that implements the two sum algorithm."
chat_completion, chosen_classifier = make_request_to_router(PROMPT, "task_router")

print(f"Prompt was classified as {chosen_classifier} & handled by model: {chat_completion.model}")
print(chat_completion.choices[0].message.content)

# %% [markdown]
# The example above requested code generation and was classified accordingly, being routed to a the configured code generation LLM. A simpler rewrite prompt is classified and routed to accordingly. For example:

# %%
PROMPT = "Rewrite this prompt to be better suited for a LLM. Prompt: Tell me about polar bears"
chat_completion, chosen_classifier = make_request_to_router(PROMPT, "task_router")

print(f"Prompt was classified as {chosen_classifier} & handled by model: {chat_completion.model}")
print(chat_completion.choices[0].message.content)

# %% [markdown]
# You can also make requests to the router directly through a curl request. For an example look at `src/test_router.sh`.

# %% [markdown]
# ### Understanding classifications
#
# Invoking the router leads to a two step process:
#
# 1. The user's prompt is classified based on the router controller policy
#
# 2. Based on the classification, the request is forwarded to the downstream LLM
#
# By default, the router proxies back a response that is identical to an OpenAI API. If you want to see details of the router's classification system you can bypass the proxy and directly interact with the router policy model. The code below shows how a prompt would be classified with the task router policy.
#
# *Note*: You can also see how a prompt is routed by viewing the router logs during a request. Run `docker compose logs router-controller -f` while making a request to see the details. You can also inspect the headers from the request to see information about the prompt classification if you use a client that returns the header values. Finally, aggregate metrics about prompt classification and routing are visible through a metrics service as described in the [Metrics](#view-metrics) section.

# %%
import numpy as np
import tritonclient.http as httpclient
from transformers import AutoConfig
import warnings
import yaml
warnings.filterwarnings('ignore')

PROMPT = "Can you write me a song?  Use as many emojis as possible."

def send_request(triton_client, text):
    input_text = np.array([[text]], dtype=object)
    inputs = [httpclient.InferInput("INPUT", input_text.shape, "BYTES")]
    inputs[0].set_data_from_numpy(input_text)

    outputs = [httpclient.InferRequestedOutput("OUTPUT")]

    response = triton_client.infer(model_name="task_router_ensemble", inputs=inputs, outputs=outputs)
    return response

# Load the config
config = AutoConfig.from_pretrained("nvidia/prompt-task-and-complexity-classifier")

with open("../src/router-controller/config.yaml", 'r') as file:
    router_config = yaml.safe_load(file) 

models = [llm['model'] for llm in router_config['policies'][0]['llms']]

# Make the request
triton_client = httpclient.InferenceServerClient(url="127.0.0.1:8000")
result = send_request(triton_client, PROMPT)

# Format the output
output_data = result.as_numpy("OUTPUT")
predicted_task_index = np.argmax(output_data)

task_types = list(config.task_type_map.values())
predicted_task = task_types[predicted_task_index]
predicted_model = models[predicted_task_index]

print(f"Using policy: task_router")
print(f"Input prompt: {PROMPT}")
print(f"Predicted class: {predicted_task}")
print(f"Predicted model: {predicted_model}")

# %% [markdown]
# ### Use a different policy
#
# The first test used the task router policy. You can also send requests that use the complexity router policy.

# %%
from openai import OpenAI
import os

PROMPT = "Can you write me a song?  Use as many emojis as possible."

# The following prompts showcase complexity routing, uncomment as desired

## Reasoning
# PROMPT = """
# A farmer needs to transport a wolf, a goat, and a cabbage across a river. 
# He has a boat that can only carry himself and one item at a time. 
# If left alone together, the wolf will eat the goat, and the goat will eat the cabbage. 
# How can the farmer safely transport all three items across the river?
# """

## Domain Knowledge 
# PROMPT = """
# Re-solve the classic farmer transporting a wolf, goat, and cabbage riddle using graph theory. 
# Define nodes as valid states (e.g., 'FWGC-left') and edges as permissible boat movements. Formalize the solution as a shortest-path algorithm.
# """

## Creativity
# PROMPT = """
# Write a scientific fiction story about the classic farmer transporting a wolf, goat, and cabbage riddle"
# """

chat_completion, chosen_classifier = make_request_to_router(PROMPT, "complexity_router")

print(f"Prompt was classified as {chosen_classifier} & handled by model: {chat_completion.model}")
print(chat_completion.choices[0].message.content)

# %% [markdown]
# ## Use the example app

# %% [markdown]
# The blueprint also includes an example client application that is useful for testing different prompts and routing policies.

# %%
# !cd llm-router && make app > /dev/null 2>&1

# %% [markdown]
# The app will be accessible at `http://localhost:8008`.
#
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## View metrics
#
# The LLM Router automatically emits metrics to help you track behavior. To see these metrics, run `make metrics` from the repository root, or `cd llm-router && make metrics` from the launchable notebook directory. This make command will launch Prometheus and Grafana.
# - Open Grafana by navigating to `http://localhost:3000`
# - Login using the default credentials, username: `admin` and passwords: `secret`.
# - Select "Data source" and pick "Prometheus". Enter `http://prometheus:9090` as the Prometheus URL.
# - Use the Grafana "Explore" query interfaces to look at available metrics.
#
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Next Steps
#
# The LLM Router is running and you know how to adapt your OpenAI API code to use it. Further explore:
#
# - Customization: The LLM Router directs requests to backend models based on the config file `src/router-controller/config.yml`. Update the model endpoints in this file to change the backend routing behaviors. You may also wish to customize the router, see `customize/README.md` for details.
#
# - Performance: This blueprint includes a sample load test that can be run against the router. Metrics are automatically created and stored in a Grafana dashboard. To get started, run `make loadtest`.

# %% [markdown]
# ## Stopping Services and Cleaning Up
#
# To shut down the microservices, run the following command

# %%
# !cd .. && make down
